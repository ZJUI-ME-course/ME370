# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %%
from sympy import solve,S,sin,cos,pi
#from math import sin,cos,pi
import sympy as sy

a3,a4=S('a3,a4')

l1=2
l2=2.5
l3=1
l4=2.5

#case 1

theta2=pi/2
theta3=pi/2
theta4=143.13*pi/180
w2=-2
w3=-5
w4=0
a2=0

equ1=-l2*a2*sin(theta2)-l2*w2**2*cos(theta2)-(-l3*a3*sin(theta3)-l3*w3**2*cos(theta3)-l4*a4*sin(theta4)-l4*w4**2*cos(theta4))
equ2=l2*a2*cos(theta2)-l2*w2**2*sin(theta2)-(l3*a3*cos(theta3)-l3*w3**2*sin(theta3)+l4*a4*cos(theta4)-l4*w4**2*sin(theta4))

sy.init_printing()

a4_value=solve(equ2)[0]
equ1=equ1.subs(a4,a4_value)
a3_value=solve(equ1)[0]

a3_value,a4_value
# Out:
# (11.2500418692051, -7.50001004862119)

# %%
# case 2

theta2=53.1301*pi/180
theta3=0
theta4=pi-theta2
w=-2
w3=-6
w4=-2
a2=0

equ1=-l2*a2*sin(theta2)-l2*w2**2*cos(theta2)-(-l3*a3*sin(theta3)-l3*w3**2*cos(theta3)-l4*a4*sin(theta4)-l4*w4**2*cos(theta4))
equ2=l2*a2*cos(theta2)-l2*w2**2*sin(theta2)-(l3*a3*cos(theta3)-l3*w3**2*sin(theta3)+l4*a4*cos(theta4)-l4*w4**2*sin(theta4))

sy.init_printing()

#solve([equ1,equ2])

a4_value=solve(equ1)[0]
equ2=equ2.subs(a4,a4_value)
a3_value=solve(equ2)[0]

a3_value,a4_value
# Out:
# (-18.0000009861066, -12.0000000410878)
