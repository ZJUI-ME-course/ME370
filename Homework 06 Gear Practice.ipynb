# %%
import math
from sympy import S,solve

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="250"/>
# </div>
#
# <div>
# <img src="attachment:image-2.png" width="350"/>
# </div>

# %%
Ns,Nr,ws,wr,wa=S('Ns,Nr,ws,wr,wa')

Ns=40
Nr=80
#ws=-30
wr=-10
wa=10

equ=Ns*ws+Nr*wr-(Ns+Nr)*wa
solve(equ)
# Out:
# [50]
