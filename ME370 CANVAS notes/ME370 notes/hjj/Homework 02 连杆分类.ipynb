# %% [markdown]
# ### **重点知识**
# 1. ***4***连杆
# 2. ***6***连杆-同构体 isomer
# 3. $DOF$加减法则
#
# ### **重点题目**
# T3 ***6***连杆-同构体⭐
# T4 ***6***连杆-同构体⭐
# T5 连杆变换法则⭐⭐
# T6 连杆变换法则⭐⭐

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="700"/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="600"/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="600"/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:image-2.png" width="600"/>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Case 1: $L_1=5,L_2=3,L_3=3,L_4=4$
# ClassⅡ  +  Parallelogram
# #### Case 2: $L_1=5,L_2=5,L_3=4,L_4=4$
# ClassⅢ  +  Deltoid class
# #### Case 3: $L_1=5,L_2=4,L_3=3,L_4=5$
# ClassⅠ  +  Double-Rocker
# #### Case 4: $L_1=3,L_2=5,L_3=4,L_4=5$
# ClassⅠ  +  Double-Crank
# #### Case 5: $L_1=5,L_2=3,L_3=4,L_4=5$
# ClassⅠ  +  Crank-Rocker

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
