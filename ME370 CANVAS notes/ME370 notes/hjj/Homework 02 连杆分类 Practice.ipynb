# %% [markdown]
# <center><font size ="6">锁紧利用</font></center>
#
# &nbsp;
# &nbsp;
#
# <div>
# <img src="attachment:image.png" width="600"/>
# </div>

# %% [markdown]
# <center><font size ="6">考部件名称</font></center>
#
# &nbsp;
# &nbsp;
# &nbsp;
#
# <div>
# <img src="attachment:image.png" width="600"/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="600"/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="600"/>
# </div>

# %% [markdown]
# # 6连杆

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>
#
# ## ???!!!! 目前解释为triple link 有相互直接连接，所以为 watt
