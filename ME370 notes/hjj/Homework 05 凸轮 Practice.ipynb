# %% [markdown]
# <center><font size ="6">改进正弦</font></center>
#
# &nbsp;
#
# <div>
# <img src="attachment:image.png" width="400"/>
# </div>

# %% [markdown]
# <center><font size ="6">梯形法</font></center>
#
# &nbsp;
#
# <div>
# <img src="attachment:image.png" width="400"/>
# </div>
