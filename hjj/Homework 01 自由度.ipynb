# %% [markdown]
# ### **重点知识**
# 1.齿轮-齿轮 齿轮-齿条 均为$J_2$
# 2.多重节点$-1$
# 3.注意**地面**也算一个$n$
#
# ### **计算公式**
# $DOF=3\cdot(n-1)-2\cdot J_1 -J_2$
#
# ### **重点题目**
# T1 模棱两可
# T4 啮合⭐
# T5 平行⭐⭐
# T6 啮合+多节点⭐⭐⭐
# T7 常规 ⭐

# %% [markdown]
# ## DOF计算器

# %%
n=int(input('n ='))
j1=int(input('J1='))
j2=int(input('J2='))
print(3*(n-1)-2*j1-j2)
# Out:
# -3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $n=5$
#
# $J_1=3$
#
# $J_2=4$
#
# $DOF=3\cdot(n-1)-2\cdot J_1 -J_2=2$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $n=5$
#
# $J_1=5$
#
# $J_2=1$
#
# $DOF=3\cdot(n-1)-2\cdot J_1 -J_2=1$

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# $n=7$
#
# $J_1=7$
#
# $J_2=1$
#
# $DOF=3\cdot(n-1)-2\cdot J_1 -J_2=3$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $n=5$
#
# $J_1=4$
#
# $J_2=3$
#
# $DOF=3\cdot(n-1)-2\cdot J_1 -J_2=1$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $n=5$
#
# $J_1=5$
#
# $J_2=1$
#
# $DOF=3\cdot(n-1)-2\cdot J_1 -J_2=1$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $n=6$
#
# $J_1=5$
#
# $J_2=3$
#
# $DOF=3\cdot(n-1)-2\cdot J_1 -J_2=2$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $n=5$
#
# $J_1=5$
#
# $J_2=1$
#
# $DOF=3\cdot(n-1)-2\cdot J_1 -J_2=1$
